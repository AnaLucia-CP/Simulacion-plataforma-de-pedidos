# %%
# !pip install simpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: simpy in c:\users\a.caballerop\appdata\roaming\python\python39\site-packages (4.0.2)

# %%
import simpy
import random
import csv
import pandas as pd

# %% [markdown]
# # SIMULACIÓN MODELO SUBASTA MEJORADA

# %%
import simpy
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from geopy.distance import great_circle
import pandas as pd
import os
import openpyxl
from openpyxl.drawing.image import Image

class RechazoDomiciliario:
    def __init__(self):
        self.probabilidad = 0
        
    def establecer_probabilidad(self, nueva_probabilidad):
        self.probabilidad = nueva_probabilidad

    def rechazar(self):
        return random.random() <= self.probabilidad

class Plataforma:
    def __init__(self, env, domiciliarios, tiendas, platform_time):
        self.env = env
        self.domiciliarios = domiciliarios
        self.tiendas = tiendas
        self.platform_time = platform_time
        self.tiempo_disponibilidad = {} # Aquí almacenaremos los tiempos de disponibilidad de los domiciliarios
        self.rechazo_domiciliario = RechazoDomiciliario()
        self.pedidos_rechazados = 0
        #self.ordenes_reasignadas = 0
        self.ganancia_total_domiciliarios = 0
        self.ganancia_total_tiendas = 0
        self.ganancia_total_plataforma = 0
        self.ventas_totales = 0
        self.ordenes_perdidas = []  # Lista para almacenar las órdenes perdidas
        self.rechazos_por_orden = {}  # Diccionario para llevar el conteo de rechazos por orden
        self.ganancias_perdidas_tiendas = 0
        self.ganancias_perdidas_plataforma = 0
        self.ganancias_perdidas_domiciliarios = 0
        self.pago_tienda_a_plataforma = 0
        self.registro_domiciliarios = {}


    def obtener_tienda_por_id(self, store_id):
        tienda = self.tiendas.loc[self.tiendas['store_id'] == store_id]
        if not tienda.empty:
            return tienda.iloc[0]
        return None

    def obtener_domiciliarios_disponibles(self, orden, capacidad_domiciliario):
        domiciliarios_disponibles = []

        tiempo_actual = orden.placement_time

        for index, domiciliario in self.domiciliarios.iterrows():
            domiciliario_id = domiciliario['courier_id']
            tiempo_disponibilidad = self.tiempo_disponibilidad.get(domiciliario_id, tiempo_actual)

            dist = great_circle((orden.drop_off_lat, orden.drop_off_lng), (domiciliario['on_lat'], domiciliario['on_lng'])).kilometers

            if tiempo_disponibilidad <= tiempo_actual and dist <= capacidad_domiciliario:
                domiciliarios_disponibles.append(domiciliario)

        return domiciliarios_disponibles

    def procesar_orden(self, orden, lista_salida, lista_no_procesadas):
        tiempo_actual = orden.placement_time
        print(f"Tiempo: {tiempo_actual.strftime('%H:%M:%S')}: La Plataforma ha recibido la orden {orden.order_id}")

        tienda = self.obtener_tienda_por_id(orden.store_id)
        if tienda is not None:
            print(f"Tiempo: {tiempo_actual.strftime('%H:%M:%S')}: La Plataforma ha informado a la tienda {orden.store_id}")
                         
        dist_tienda_cliente = great_circle((tienda['pick_up_lat'], tienda['pick_up_lng']),
                                           (orden.drop_off_lat, orden.drop_off_lng)).kilometers
        
        print(f"Distancia entre la tienda y el cliente: {dist_tienda_cliente:.2f}")
        capacidad_domiciliario = 5
                
        if lista_salida is None:
            lista_salida = []
        if lista_no_procesadas is None:
            lista_no_procesadas = []

            
        domiciliarios_disponibles = self.obtener_domiciliarios_disponibles(orden, capacidad_domiciliario)
        #domiciliarios_disponibles.sort(key=lambda d: great_circle((tienda['pick_up_lat'], tienda['pick_up_lng']), (d['on_lat'], d['on_lng'])).kilometers)
        
        if domiciliarios_disponibles:
            domiciliario_mas_cercano = None
            distancia_mas_cercana = float('inf')

            for domiciliario in domiciliarios_disponibles:
                domiciliario_id = domiciliario['courier_id']
                dist = great_circle((orden.drop_off_lat, orden.drop_off_lng),
                                    (domiciliario['on_lat'], domiciliario['on_lng'])).kilometers

                if dist < distancia_mas_cercana:
                    domiciliario_mas_cercano = domiciliario
                    distancia_mas_cercana = dist

            if domiciliario_mas_cercano is not None:
                domiciliario_id = domiciliario_mas_cercano['courier_id']
                
                
        #Definir el costo según la distancia
        costo_fijo_por_km = 1000 
        costo_por_distancia = dist_tienda_cliente * costo_fijo_por_km
        print(f"Costo según la distancia: {costo_por_distancia:.2f}")
        
        incremento_por_rechazo = costo_por_distancia / 10 # Calcular la décima parte del costo por distancia
        
        num_rechazos = self.rechazos_por_orden.get(orden.order_id, 0) # Obtener el número de rechazos previos de esta orden
        
        # Ajustar el valor ofrecido basado en el número de rechazos
        valor_ofrecido_domicilio = 2000
        print(f"Valor ofrecido por domicilio {valor_ofrecido_domicilio:.2f}")
                
        # Ajustar la probabilidad de rechazo basado en el costo por distancia

        # Crear un objeto de RechazoDomiciliario con la probabilidad ajustada
        rechazo_domiciliario = RechazoDomiciliario()

        for domiciliario in domiciliarios_disponibles:
            domiciliario_id = domiciliario['courier_id']
            
            # RECHAZOS -- > Inicializar contador de rechazos si es necesario
            if orden.order_id not in self.rechazos_por_orden:
                self.rechazos_por_orden[orden.order_id] = 0
                
            if valor_ofrecido_domicilio >= costo_por_distancia:
                probabilidad_rechazo = 0.2
            else:  
                probabilidad_rechazo = 0.8

            if random.random() <= probabilidad_rechazo:
                # Incrementar el contador de rechazos
                num_rechazos += 1
                self.rechazos_por_orden[orden.order_id] = num_rechazos
                valor_ofrecido_domicilio = incremento_por_rechazo * (self.rechazos_por_orden[orden.order_id]) + 2000
                tiempo_actual += timedelta(minutes=2)
                print(f"Domiciliario {domiciliario_id} ha rechazado la orden {orden.order_id}. {num_rechazos}")
                print(f"Valor ofrecido por domicilio {valor_ofrecido_domicilio:.2f}")
                

                if self.rechazos_por_orden[orden.order_id] >= 5:
                    print(f"Orden {orden.order_id} rechazada definitivamente.")
                    self.ordenes_perdidas.append(orden.order_id)

                    costo_orden_perdida = random.uniform(40000, 100000)
                    ganancia_tienda_perdida = costo_orden_perdida
                    ganancia_plataforma_perdida = costo_orden_perdida * random.gauss(0.1, 0.2)
                    ganancia_domiciliario_perdida = valor_ofrecido_domicilio
                    costo_usuario_perdida = costo_orden_perdida + ganancia_domiciliario_perdida
                    
                    #Acumular ganancias perdidas por rechazos definitivos
                    self.ganancias_perdidas_tiendas += costo_orden_perdida
                    self.ganancias_perdidas_plataforma += ganancia_plataforma_perdida
                    self.ganancias_perdidas_domiciliarios += ganancia_domiciliario_perdida
                    break  # Salir del bucle, la orden ha sido rechazada definitivamente

            else:
                print(f"Tiempo: {tiempo_actual.strftime('%H:%M:%S')}: Domiciliario {domiciliario_id} asignado a la orden {orden.order_id}")
                
            #CUANDO ES ASIGNADO SE REALIZA TOOOODO LO DEMÁS PARA LLEVAR A CABO EL DOMICILIO                        
            # Asignar la velocidad del domiciliario según el tipo de vehículo
                tipo_vehiculo = domiciliario['vehicle']
                if tipo_vehiculo == 'motorcycle':
                    velocidad_domiciliario = 23
                elif tipo_vehiculo == 'bicycle':
                    velocidad_domiciliario = 12
                elif tipo_vehiculo == 'car': 
                    velocidad_domiciliario = 20
                elif tipo_vehiculo == 'walking':
                    velocidad_domiciliario = 5
                else:
                    velocidad_domiciliario = 30  # Velocidad por defecto si no se especifica el tipo de vehículo
                
                tiempo_ida_domiciliario = distancia_mas_cercana / velocidad_domiciliario
                tiempo_ida_domiciliario = timedelta(hours=tiempo_ida_domiciliario)
                print(f"Tiempo de ida del domiciliario a la tienda: {tiempo_ida_domiciliario}")
                
                time_difference = orden.ready_time - orden.placement_time
                
                tiempo_maximo = max(tiempo_ida_domiciliario, time_difference)
                
                tiempo_a_cliente = dist_tienda_cliente / velocidad_domiciliario
                tiempo_a_cliente = timedelta(hours=tiempo_a_cliente)
                print(f"Tiempo estimado del domiciliario al cliente: {tiempo_a_cliente} horas")

                tiempo_entrega = tiempo_ida_domiciliario + tiempo_a_cliente + tiempo_maximo
                tiempo_entrega = round(tiempo_entrega.total_seconds() / 60, 2)
                print(f"Tiempo estimado de entrega: {tiempo_entrega} minutos")
                tiempo_entrega_timedelta = timedelta(minutes=tiempo_entrega)
                
                tiempo_vuelta_base = tiempo_ida_domiciliario + tiempo_a_cliente   # Tiempo de regreso a la base
                print(f"Tiempo estimado en regreso al punto inicial el domiciliario: {tiempo_vuelta_base} horas")
                
                tiempo_disponibilidad_domiciliario = tiempo_entrega_timedelta + tiempo_actual + tiempo_vuelta_base
                print(f"Domiciliario {domiciliario_id} estará disponible a las {tiempo_disponibilidad_domiciliario.strftime('%H:%M:%S')}")
                
                costo_orden = random.uniform(40000, 100000)
                pago_tienda_a_plataforma = costo_orden * random.uniform(0.1, 0.2)
                ganancia_tienda = costo_orden - pago_tienda_a_plataforma
                costo_servicio = costo_orden * random.gauss(0.1, 0.03)
                ganancia_domiciliario = valor_ofrecido_domicilio
                costo_usuario = costo_orden + ganancia_domiciliario + costo_servicio
                if costo_por_distancia > ganancia_domiciliario:
                    sobrante_costo_por_distancia = costo_por_distancia - ganancia_domiciliario
                else:
                    sobrante_costo_por_distancia = 0
                ganancia_plataforma = pago_tienda_a_plataforma + sobrante_costo_por_distancia + costo_servicio
                                    
                # Actualizar las ganancias totales
                self.ganancia_total_domiciliarios += ganancia_domiciliario
                self.ganancia_total_tiendas += ganancia_tienda
                self.ganancia_total_plataforma += ganancia_plataforma
                self.ventas_totales += costo_usuario

                lista_salida.append({
                    'Orden': orden.order_id,
                    'Domiciliario': domiciliario_id,
                    'Tiempo de Ida': tiempo_ida_domiciliario.total_seconds() / 3600,
                    'Tiempo en Tienda': orden.preparation_time,
                    'Tiempo de Entrega': tiempo_entrega,
                    'Ganancia Domiciliario': ganancia_domiciliario,
                    'Costo orden': costo_orden,
                    'Costo de servicio':costo_servicio,
                    'Tienda': tienda,
                    'Ganancia tienda':ganancia_tienda,
                    'Pago tienda a plataforma':pago_tienda_a_plataforma,
                    'Costo por Distancia': costo_por_distancia
                })

                #print(f"Ganancia del domiciliario: {ganancia_domiciliario:.2f}")
                #print(f"Costo Total al Usuario: {costo_usuario:.2f}")
                #print(f"Los otros costos son: costo de la orden: {costo_orden}, pago tienda a plataforma: {pago_tienda_a_plataforma:.2f}, Ganancia de la tienda: {ganancia_tienda:.2f}, Ganancia de la plataforma: {ganancia_plataforma:.2f}, sobrante costo por distancia: {sobrante_costo_por_distancia:.2f}")

                self.tiempo_disponibilidad[domiciliario_id] = tiempo_disponibilidad_domiciliario


                break
                   

#Cargar archivos CSV
carpeta_principal = 'Instancias'
subcarpeta = 'Instancia_3'

ruta_domiciliarios = os.path.join(carpeta_principal, subcarpeta, 'couriers.csv')
ruta_tiendas = os.path.join(carpeta_principal, subcarpeta, 'stores.csv')
ruta_ordenes = os.path.join(carpeta_principal, subcarpeta, 'orders.csv')

# Leer los archivos CSV
df_domiciliarios = pd.read_csv(ruta_domiciliarios)
df_tiendas = pd.read_csv(ruta_tiendas)
df_ordenes = pd.read_csv(ruta_ordenes)

# Define el tiempo de inicio y finalización de la simulación
tiempo_inicio_simulacion = datetime.strptime("00:00:00", "%H:%M:%S")
tiempo_finalizacion_simulación = datetime.strptime("23:59:00", "%H:%M:%S")

# Filtra las órdenes en el rango de tiempo
df_ordenes['placement_time'] = pd.to_datetime(df_ordenes['placement_time'])
df_ordenes['ready_time'] = pd.to_datetime(df_ordenes['ready_time'])
df_ordenes['expected_drop_off_time'] = pd.to_datetime(df_ordenes['expected_drop_off_time'])
df_ordenes_filtradas = df_ordenes[
    (df_ordenes['placement_time'].dt.strftime('%H:%M:%S') >= tiempo_inicio_simulacion.strftime('%H:%M:%S')) &
    (df_ordenes['placement_time'].dt.strftime('%H:%M:%S') <= tiempo_finalizacion_simulación.strftime('%H:%M:%S'))
]

# Crear un entorno de simulación
env = simpy.Environment()

# Crear listas para almacenar los resultados
lista_salida = []
lista_no_procesadas = []

# Simular el procesamiento de órdenes
platform_time = 2

plataforma = Plataforma(env, df_domiciliarios, df_tiendas, platform_time)

# Inicializar el tiempo actual al inicio de la simulación
tiempo_actual = tiempo_inicio_simulacion

# Definir la clase Orden
class Orden:
    def __init__(self, env, order_id, store_id, drop_off_lat, drop_off_lng, placement_time, preparation_time, ready_time, expected_drop_off_time):
        self.env = env
        self.order_id = order_id
        self.store_id = store_id
        self.drop_off_lat = drop_off_lat
        self.drop_off_lng = drop_off_lng
        self.placement_time = datetime.strptime(placement_time, "%H:%M:%S")
        self.preparation_time = preparation_time
        self.ready_time = datetime.strptime(ready_time, "%H:%M:%S")
        self.expected_drop_off_time = datetime.strptime(expected_drop_off_time, "%H:%M:%S")

    def tiempo_entrega_estimado(self):
        tiempo_ida_tienda = great_circle((df_tiendas.at[self.store_id, 'pick_up_lat'], df_tiendas.at[self.store_id, 'pick_up_lng']), (self.drop_off_lat, self.drop_off_lng)).kilometers / 30
        tiempo_ida_tienda = timedelta(hours=tiempo_ida_tienda)
        tiempo_entrega_estimado = tiempo_ida_tienda + timedelta(minutes=self.preparation_time)
        return tiempo_entrega_estimado

# Procesar todas las órdenes en df_ordenes_filtradas
for index, orden_row in df_ordenes_filtradas.iterrows():
    placement_time = orden_row['placement_time']
    ready_time = orden_row['ready_time']
    expected_drop_off_time = orden_row['expected_drop_off_time']

    orden = Orden(
        env,
        orden_row['order_id'],
        orden_row['store_id'],
        orden_row['drop_off_lat'],
        orden_row['drop_off_lng'],
        orden_row['placement_time'].strftime("%H:%M:%S"),  # Convierte a cadena
        random.randint(5, 15),
        orden_row['ready_time'].strftime("%H:%M:%S"),  # Convierte a cadena
        orden_row['expected_drop_off_time'].strftime("%H:%M:%S")  # Convierte a cadena
    )

    plataforma.procesar_orden(orden, lista_salida, lista_no_procesadas)

# Realizar la simulación sin restricciones de tiempo
env.run()

#Imprimir ganancias y ventas totales
print(f"Ganancia Total Domiciliarios: {round(plataforma.ganancia_total_domiciliarios, 2)}")
print(f"Ganancia Total Tiendas: {round(plataforma.ganancia_total_tiendas,2)}")
print(f"Ganancia Total Plataforma: {round(plataforma.ganancia_total_plataforma,2)}")
print(f"Ventas Totales (Costo Total al Usuario): {round(plataforma.ventas_totales,2)}")

# Imprimir el número de pedidos rechazados
print("Órdenes Perdidas:", plataforma.ordenes_perdidas)

#Imprimir ganancias perdidas por rechazos definitivos
print(f"Ganancias perdidas - Domiciliarios: {plataforma.ganancias_perdidas_domiciliarios}")
print(f"Ganancias perdidas - Tiendas: {plataforma.ganancias_perdidas_tiendas}")
print(f"Ganancias perdidas - Plataforma: {plataforma.ganancias_perdidas_plataforma}")

### EXPORTAR RESULTADOS A EXCEL

# ----> Para Domiciliarios

# Crear un DataFrame a partir de lista_salida
df = pd.DataFrame(lista_salida)

# Contar cuántas órdenes hizo cada domiciliario
orden_por_domiciliario = df['Domiciliario'].value_counts().reset_index()
orden_por_domiciliario.columns = ['Domiciliario', 'Cantidad de Órdenes']

ganancia_por_domiciliario = df.groupby('Domiciliario')['Ganancia Domiciliario'].sum().reset_index()
ganancia_por_domiciliario.columns = ['Domiciliario', 'Ganancia Total']

df_domiciliarios.set_index('courier_id', inplace=True)
df_final_domiciliarios = df_domiciliarios.join(orden_por_domiciliario.set_index('Domiciliario'))
df_final_domiciliarios = df_final_domiciliarios.join(ganancia_por_domiciliario.set_index('Domiciliario'))

# Reordenar y renombrar las columnas para el formato deseado
df_final_domiciliarios = df_final_domiciliarios[['vehicle', 'Cantidad de Órdenes', 'Ganancia Total']]
df_final_domiciliarios.reset_index(inplace=True)
df_final_domiciliarios.columns = ['courier_id', 'Tipo de Vehiculo', 'Total de Ordenes Atendidas', 'Ganancia Total']

# -----> Para ordenes

# Convertir lista_salida a DataFrame y realizar los cálculos necesarios
df_ordenes_completadas = pd.DataFrame(lista_salida)
df_ordenes_completadas['Hora de Entrega'] = df_ordenes_completadas['Tiempo de Ida'] + df_ordenes_completadas['Tiempo en Tienda'] + df_ordenes_completadas['Tiempo de Entrega']
df_ordenes_completadas['Hora de Entrega'] = df_ordenes_completadas['Hora de Entrega'].apply(lambda x: timedelta(hours=x) + tiempo_inicio_simulacion)

# Unir con df_ordenes para obtener los costos y rechazos
df_rechazos = pd.DataFrame.from_dict(plataforma.rechazos_por_orden, orient='index').reset_index()
df_rechazos.columns = ['Orden', 'Número de Rechazos']

# Unir df_rechazos con df_final_ordenes
df_final_ordenes = df_ordenes_completadas.merge(df_rechazos, on='Orden', how='left')

df_final_ordenes['Hora de Entrega'] = pd.to_datetime(df_final_ordenes['Hora de Entrega'])
df_final_ordenes['Hora de Entrega'] = df_final_ordenes['Hora de Entrega'].dt.strftime('%H:%M:%S')

# Seleccionar y renombrar columnas
df_final_ordenes = df_final_ordenes[['Orden', 'Costo orden', 'Número de Rechazos', 'Costo de servicio', 'Tiempo de Entrega', 'Hora de Entrega', 'Costo por Distancia', 'Ganancia Domiciliario']]
#df_final_ordenes.reset_index(inplace=True)
df_final_ordenes.columns = ['Order ID', 'Costo de la Orden', 'Número Total de Rechazos', 'Costo de servicio', 'Tiempo de Entrega', 'Hora de Entrega', 'Costo justo por distancia', 'Ganancia del domiciliario']


# --------> Para tiendas

df_ordenes_completadas['store_id'] = df_ordenes_completadas['Tienda'].apply(lambda x: x['store_id'])
pedidos_por_tienda = df_ordenes_completadas['store_id'].value_counts().reset_index()
pedidos_por_tienda.columns = ['store_id', 'Cantidad de Pedidos']

# Calcular la ganancia total y el pago a la plataforma por cada tienda
df_ganancias_tiendas = df_ordenes_completadas.groupby('store_id').agg({'Ganancia tienda':'sum', 'Pago tienda a plataforma':'sum'}).reset_index()

# Unir la información en un solo DataFrame
df_info_tiendas = pd.merge(pedidos_por_tienda, df_ganancias_tiendas, on='store_id')

# ---------> Para plataforma y total

# Crear un diccionario con los datos de la plataforma
datos_plataforma = {
    'Descripción': ['Ganancia plataforma', 'Ventas totales', 'Ganancia total domiciliarios', 'Ganancia total tiendas', 'Costo de oportunidad por ordenes rechazadas definitivamente', 'Total ordenes rechazadas definitivamente', 'Ganancias perdidas tiendas', 'Ganancias perdidas plataforma', 'Ganancias perdidas domiciliarios'],
    'Valor': [
        plataforma.ganancia_total_plataforma, 
        plataforma.ventas_totales, 
        plataforma.ganancia_total_domiciliarios, 
        plataforma.ganancia_total_tiendas, 
        '', # Costo de oportunidad no se calculó en el código, así que se deja en blanco o se agrega un cálculo si lo tienes
        len(plataforma.ordenes_perdidas), 
        plataforma.ganancias_perdidas_tiendas, 
        plataforma.ganancias_perdidas_plataforma, 
        plataforma.ganancias_perdidas_domiciliarios
    ]
}

# Convertir el diccionario en un DataFrame
df_plataforma = pd.DataFrame(datos_plataforma)

#---------> Para gráficos

#Domiciliarios por Hora
# Convertir las columnas 'on_time' y 'off_time' a tipo datetime
df_domiciliarios['on_time'] = pd.to_datetime(df_domiciliarios['on_time'], format='%H:%M:%S').dt.time
df_domiciliarios['off_time'] = pd.to_datetime(df_domiciliarios['off_time'], format='%H:%M:%S').dt.time

# Crear un DataFrame para cada hora del día
hours = [hour.time() for hour in pd.date_range("00:00", "23:59", freq="H")]
availability_df = pd.DataFrame(hours, columns=['hour'])

# Contar los domiciliarios disponibles para cada hora
availability_df['count'] = availability_df['hour'].apply(
    lambda hour: ((df_domiciliarios['on_time'] <= hour) & (df_domiciliarios['off_time'] >= hour)).sum()
)

# Crear un gráfico para mostrar la disponibilidad de domiciliarios por hora
plt.figure(figsize=(12, 6))
plt.bar(availability_df['hour'].astype(str), availability_df['count'])
plt.title('Disponibilidad de Domiciliarios por Hora')
plt.xlabel('Hora')
plt.ylabel('Cantidad de Domiciliarios Disponibles')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.tight_layout()

## Ordenes por hora
# Convertir la columna 'placement_time' a tipo datetime
df_ordenes['placement_time'] = pd.to_datetime(df_ordenes['placement_time'])

# Agrupar por hora y contar las ordenes
order_counts_per_hour = df_ordenes['placement_time'].dt.floor('H').value_counts().sort_index()

# Creando el gráfico
plt.figure(figsize=(12, 6))
order_counts_per_hour.plot(kind='bar')
plt.xticks(ticks=range(len(order_counts_per_hour)), labels=[t.strftime('%H:%M') for t in order_counts_per_hour.index])
plt.title('Cantidad de Órdenes por Hora')
plt.xlabel('Hora')
plt.ylabel('Cantidad de Órdenes')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()

# Datos de la tabla
datos_tabla = {
    "Categoría": ['Sin Rechazo', '1 Rechazo', '2 Rechazos','3 Rechazos', '4 Rechazos', 'Rechazadas Definitivamente'],
    "Cantidad de Órdenes": [ordenes_aceptadas_sin_rechazo, ordenes_rechazadas_una_vez, ordenes_rechazadas_dos_veces, 
                            ordenes_rechazadas_tres_veces, ordenes_rechazadas_cuatro_veces, ordenes_rechazadas_definitivamente]
}

# Crear DataFrame
df = pd.DataFrame(datos_tabla)

# Exportar gráfico a una imagen
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(df["Categoría"], df["Cantidad de Órdenes"], color=['blue', 'green', 'orange', 'red'])
plt.title('Distribución de Órdenes Basada en Rechazos')
plt.xlabel('Categoría')
plt.ylabel('Cantidad de Órdenes')


output_folder = 'outputs_ModeloSubastaMejorada'
excel_path = os.path.join(output_folder, 'resultadosIns_3.xlsx')

# Guardar gráfico como imagen
ruta_imagen_1 = os.path.join(output_folder, 'grafico_rechazosIns_3.png')

plt.savefig(ruta_imagen_1)

# Añadir el grafico de cantidad de ordenes y domiciliarios
plt.figure(figsize=(15, 8))
plt.plot(full_hours_str, order_counts_per_hour_full.values, label='Órdenes por Hora', color='blue', marker='o', linestyle='-', linewidth=2)
plt.plot(full_hours_str, availability_df['count'], color='red', marker='o', linestyle='-', linewidth=2, label='Domiciliarios Disponibles')
plt.title('Órdenes y Domiciliarios Disponibles por Hora')
plt.xlabel('Hora')
plt.ylabel('Cantidad')
plt.xticks(full_hours_str, rotation=90)
plt.grid(axis='y')
plt.legend()
plt.tight_layout()

# Guardar el gráfico como imagen
ruta_imagen_2 = os.path.join(output_folder, 'grafico_DisponiblesIns_3.png')
plt.savefig(ruta_imagen_2)

with pd.ExcelWriter(excel_path, engine='openpyxl') as writer:
    df_final_domiciliarios.to_excel(writer, sheet_name='Domiciliarios', index=False)
    df_final_ordenes.to_excel(writer, sheet_name='Órdenes', index=False)
    df_info_tiendas.to_excel(writer, sheet_name='Tiendas', index=False)
    df_plataforma.to_excel(writer, sheet_name='Plataforma', index=False)
    df.to_excel(writer, sheet_name='Rechazos', index=False)
        # Añadir el gráfico de rechazos
book = openpyxl.load_workbook(excel_path)
sheet = book['Rechazos']

# Crea un objeto Image con la ruta de la imagen
img1 = Image(ruta_imagen_1)

# Inserta la imagen en la celda deseada
sheet.add_image(img1, 'G1')
img1.width = img1.width * 0.5  
img1.height = img1.height * 0.5

# Cargar e insertar la segunda imagen
img2 = Image(ruta_imagen_2)
sheet.add_image(img2, 'Q1')  
img2.width = img2.width * 0.5  
img2.height = img2.height * 0.5 

# Guarda los cambios en el archivo
book.save(excel_path)

rechazos_por_orden = plataforma.rechazos_por_orden
ordenes_perdidas = plataforma.ordenes_perdidas

# Mostrar la tabla de rechazos
print(f"ordenes_aceptadas_sin_rechazo: {ordenes_aceptadas_sin_rechazo}")
print(f"ordenes_rechazadas_una_vez: {ordenes_rechazadas_una_vez}")
print(f'ordenes_rechazadas_dos_veces: {ordenes_rechazadas_dos_veces}')
print(f'ordenes_rechazadas_tres_veces: {ordenes_rechazadas_tres_veces}')
print(f'ordenes_rechazadas_cuatro_veces: {ordenes_rechazadas_cuatro_veces}')
print(f'ordenes_rechazadas_definitivamente: {ordenes_rechazadas_definitivamente}')
# Out:
# Tiempo: 00:05:44: La Plataforma ha recibido la orden c1
# Tiempo: 00:05:44: La Plataforma ha informado a la tienda s1
# Distancia entre la tienda y el cliente: 1.06
# Costo según la distancia: 1064.45
# Valor ofrecido por domicilio 2000.00
# Tiempo: 00:05:44: Domiciliario c2 asignado a la orden c1
# Tiempo de ida del domiciliario a la tienda: 0:00:13.411586
# Tiempo estimado del domiciliario al cliente: 0:02:46.610313 horas
# Tiempo estimado de entrega: 22.1 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:03:00.021899 horas
# Domiciliario c2 estará disponible a las 00:30:50
# Tiempo: 00:22:35: La Plataforma ha recibido la orden c2
# Tiempo: 00:22:35: La Plataforma ha informado a la tienda s2
# Distancia entre la tienda y el cliente: 1.66
# Costo según la distancia: 1659.89
# Valor ofrecido por domicilio 2000.00
# Tiempo: 00:22:35: Domiciliario c1 asignado a la orden c2
# Tiempo de ida del domiciliario a la tienda: 0:00:18.690574
# Tiempo estimado del domiciliario al cliente: 0:04:19.808384 horas
# Tiempo estimado de entrega: 10.87 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:04:38.498958 horas
# Domiciliario c1 estará disponible a las 00:38:05
# Tiempo: 00:37:12: La Plataforma ha recibido la orden c3
# Tiempo: 00:37:12: La Plataforma ha informado a la tienda s3
# Distancia entre la tienda y el cliente: 4.94
# Costo según la distancia: 4940.36
# Valor ofrecido por domicilio 2000.00
# Domiciliario c2 ha rechazado la orden c3. 1
# Valor ofrecido por domicilio 2494.04
# Domiciliario c3 ha rechazado la orden c3. 2
# Valor ofrecido por domicilio 2988.07
# Domiciliario c4 ha rechazado la orden c3. 3
# Valor ofrecido por domicilio 3482.11
# Tiempo: 00:43:12: Domiciliario c6 asignado a la orden c3
# Tiempo de ida del domiciliario a la tienda: 0:00:14.303521
# Tiempo estimado del domiciliario al cliente: 0:12:53.273338 horas
# Tiempo estimado de entrega: 21.89 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:13:07.576859 horas
# Domiciliario c6 estará disponible a las 01:18:12
# Tiempo: 00:39:03: La Plataforma ha recibido la orden c4
# Tiempo: 00:39:03: La Plataforma ha informado a la tienda s3
# Distancia entre la tienda y el cliente: 1.86
# Costo según la distancia: 1864.38
# Valor ofrecido por domicilio 2000.00
# Tiempo: 00:39:03: Domiciliario c1 asignado a la orden c4
# Tiempo de ida del domiciliario a la tienda: 0:00:10.955269
# Tiempo estimado del domiciliario al cliente: 0:04:51.815789 horas
# Tiempo estimado de entrega: 14.46 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:05:02.771058 horas
# Domiciliario c1 estará disponible a las 00:58:33
# Tiempo: 00:39:42: La Plataforma ha recibido la orden c5
# Tiempo: 00:39:42: La Plataforma ha informado a la tienda s4
# Distancia entre la tienda y el cliente: 1.25
# Costo según la distancia: 1251.56
# Valor ofrecido por domicilio 2000.00
# Tiempo: 00:39:42: Domiciliario c2 asignado a la orden c5
# Tiempo de ida del domiciliario a la tienda: 0:00:28.605304
# Tiempo estimado del domiciliario al cliente: 0:03:15.895569 horas
# Tiempo estimado de entrega: 34.98 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:03:44.500873 horas
# Domiciliario c2 estará disponible a las 01:18:25
# Tiempo: 00:42:47: La Plataforma ha recibido la orden c6
# Tiempo: 00:42:47: La Plataforma ha informado a la tienda s5
# Distancia entre la tienda y el cliente: 5.53
# Costo según la distancia: 5532.74
# Valor ofrecido por domicilio 2000.00
# Domiciliario c4 ha rechazado la orden c6. 1
# Valor ofrecido por domicilio 2553.27
# Domiciliario c16 ha rechazado la orden c6. 2
# Valor ofrecido por domicilio 3106.55
# Domiciliario c22 ha rechazado la orden c6. 3
# Valor ofrecido por domicilio 3659.82
# Domiciliario c24 ha rechazado la orden c6. 4
# Valor ofrecido por domicilio 4213.10
# Tiempo: 00:50:47: Domiciliario c25 asignado a la orden c6
# Tiempo de ida del domiciliario a la tienda: 0:00:25.135768
# Tiempo estimado del domiciliario al cliente: 0:14:25.994547 horas
# Tiempo estimado de entrega: 42.02 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:14:51.130315 horas
# Domiciliario c25 estará disponible a las 01:47:39
# Tiempo: 00:44:51: La Plataforma ha recibido la orden c7
# Tiempo: 00:44:51: La Plataforma ha informado a la tienda s6
# Distancia entre la tienda y el cliente: 2.80
# Costo según la distancia: 2798.84
# Valor ofrecido por domicilio 2000.00
# Domiciliario c3 ha rechazado la orden c7. 1
# Valor ofrecido por domicilio 2279.88
# Domiciliario c4 ha rechazado la orden c7. 2
# Valor ofrecido por domicilio 2559.77
# Domiciliario c7 ha rechazado la orden c7. 3
# Valor ofrecido por domicilio 2839.65
# Tiempo: 00:50:51: Domiciliario c9 asignado a la orden c7
# Tiempo de ida del domiciliario a la tienda: 0:01:46.554819
# Tiempo estimado del domiciliario al cliente: 0:33:35.167727 horas
# Tiempo estimado de entrega: 61.96 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:35:21.722546 horas
# Domiciliario c9 estará disponible a las 02:28:10
# Tiempo: 00:50:00: La Plataforma ha recibido la orden c8
# Tiempo: 00:50:00: La Plataforma ha informado a la tienda s7
# Distancia entre la tienda y el cliente: 0.74
# Costo según la distancia: 744.56
# Valor ofrecido por domicilio 2000.00
# Tiempo: 00:50:00: Domiciliario c3 asignado a la orden c8
# Tiempo de ida del domiciliario a la tienda: 0:02:21.216888
# Tiempo estimado del domiciliario al cliente: 0:03:43.366664 horas
# Tiempo estimado de entrega: 57.33 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:06:04.583552 horas
# Domiciliario c3 estará disponible a las 01:53:24
# Tiempo: 00:52:35: La Plataforma ha recibido la orden c9
# Tiempo: 00:52:35: La Plataforma ha informado a la tienda s5
# Distancia entre la tienda y el cliente: 1.76
# Costo según la distancia: 1757.39
# Valor ofrecido por domicilio 2000.00
# Tiempo: 00:52:35: Domiciliario c4 asignado a la orden c9
# Tiempo de ida del domiciliario a la tienda: 0:00:08.628089
# Tiempo estimado del domiciliario al cliente: 0:04:35.069620 horas
# Tiempo estimado de entrega: 31.99 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:04:43.697709 horas
# Domiciliario c4 estará disponible a las 01:29:18
# Tiempo: 00:56:31: La Plataforma ha recibido la orden c10
# Tiempo: 00:56:31: La Plataforma ha informado a la tienda s8
# Distancia entre la tienda y el cliente: 1.49
# Costo según la distancia: 1490.26
# Valor ofrecido por domicilio 2000.00
# Tiempo: 00:56:31: Domiciliario c10 asignado a la orden c10
# Tiempo de ida del domiciliario a la tienda: 0:00:15.105872
# Tiempo estimado del domiciliario al cliente: 0:03:53.257641 horas
# Tiempo estimado de entrega: 30.32 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:04:08.363513 horas
# Domiciliario c10 estará disponible a las 01:30:58
# Tiempo: 01:22:06: La Plataforma ha recibido la orden c11
# Tiempo: 01:22:06: La Plataforma ha informado a la tienda s5
# Distancia entre la tienda y el cliente: 1.27
# Costo según la distancia: 1269.06
# Valor ofrecido por domicilio 2000.00
# Tiempo: 01:22:06: Domiciliario c2 asignado a la orden c11
# Tiempo de ida del domiciliario a la tienda: 0:00:41.130069
# Tiempo estimado del domiciliario al cliente: 0:03:18.635749 horas
# Tiempo estimado de entrega: 27.25 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:03:59.765818 horas
# Domiciliario c2 estará disponible a las 01:53:20
# Tiempo: 01:23:09: La Plataforma ha recibido la orden c12
# Tiempo: 01:23:09: La Plataforma ha informado a la tienda s8
# Distancia entre la tienda y el cliente: 1.26
# Costo según la distancia: 1256.23
# Valor ofrecido por domicilio 2000.00
# Tiempo: 01:23:09: Domiciliario c6 asignado a la orden c12
# Tiempo de ida del domiciliario a la tienda: 0:00:46.023552
# Tiempo estimado del domiciliario al cliente: 0:03:16.627419 horas
# Tiempo estimado de entrega: 26.73 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:04:02.650971 horas
# Domiciliario c6 estará disponible a las 01:53:55
# Tiempo: 01:29:28: La Plataforma ha recibido la orden c13
# Tiempo: 01:29:28: La Plataforma ha informado a la tienda s8
# Distancia entre la tienda y el cliente: 1.26
# Costo según la distancia: 1256.23
# Valor ofrecido por domicilio 2000.00
# Domiciliario c4 ha rechazado la orden c13. 1
# Valor ofrecido por domicilio 2125.62
# Tiempo: 01:31:28: Domiciliario c12 asignado a la orden c13
# Tiempo de ida del domiciliario a la tienda: 0:03:31.708340
# Tiempo estimado del domiciliario al cliente: 0:15:04.486128 horas
# Tiempo estimado de entrega: 47.02 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:18:36.194468 horas
# Domiciliario c12 estará disponible a las 02:37:05
# Tiempo: 01:45:33: La Plataforma ha recibido la orden c14
# Tiempo: 01:45:33: La Plataforma ha informado a la tienda s3
# Distancia entre la tienda y el cliente: 2.44
# Costo según la distancia: 2436.57
# Valor ofrecido por domicilio 2000.00
# Domiciliario c1 ha rechazado la orden c14. 1
# Valor ofrecido por domicilio 2243.66
# Domiciliario c7 ha rechazado la orden c14. 2
# Valor ofrecido por domicilio 2487.31
# Tiempo: 01:49:33: Domiciliario c10 asignado a la orden c14
# Tiempo de ida del domiciliario a la tienda: 0:00:11.863074
# Tiempo estimado del domiciliario al cliente: 0:06:21.376706 horas
# Tiempo estimado de entrega: 12.54 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:06:33.239780 horas
# Domiciliario c10 estará disponible a las 02:08:38
# Tiempo: 01:56:53: La Plataforma ha recibido la orden c15
# Tiempo: 01:56:53: La Plataforma ha informado a la tienda s5
# Distancia entre la tienda y el cliente: 0.81
# Costo según la distancia: 811.47
# Valor ofrecido por domicilio 2000.00
# Tiempo: 01:56:53: Domiciliario c1 asignado a la orden c15
# Tiempo de ida del domiciliario a la tienda: 0:00:06.816009
# Tiempo estimado del domiciliario al cliente: 0:02:07.013464 horas
# Tiempo estimado de entrega: 28.31 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:13.829473 horas
# Domiciliario c1 estará disponible a las 02:27:25
# Tiempo: 02:06:02: La Plataforma ha recibido la orden c16
# Tiempo: 02:06:02: La Plataforma ha informado a la tienda s9
# Distancia entre la tienda y el cliente: 1.59
# Costo según la distancia: 1592.69
# Valor ofrecido por domicilio 2000.00
# Tiempo: 02:06:02: Domiciliario c2 asignado a la orden c16
# Tiempo de ida del domiciliario a la tienda: 0:00:57.048949
# Tiempo estimado del domiciliario al cliente: 0:04:09.290936 horas
# Tiempo estimado de entrega: 11.31 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:05:06.339885 horas
# Domiciliario c2 estará disponible a las 02:22:26
# Tiempo: 02:17:40: La Plataforma ha recibido la orden c17
# Tiempo: 02:17:40: La Plataforma ha informado a la tienda s10
# Distancia entre la tienda y el cliente: 0.22
# Costo según la distancia: 219.10
# Valor ofrecido por domicilio 2000.00
# Tiempo: 02:17:40: Domiciliario c3 asignado a la orden c17
# Tiempo de ida del domiciliario a la tienda: 0:00:13.064016
# Tiempo estimado del domiciliario al cliente: 0:01:05.729943 horas
# Tiempo estimado de entrega: 17.7 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:01:18.793959 horas
# Domiciliario c3 estará disponible a las 02:36:40
# Tiempo: 02:32:04: La Plataforma ha recibido la orden c18
# Tiempo: 02:32:04: La Plataforma ha informado a la tienda s3
# Distancia entre la tienda y el cliente: 0.67
# Costo según la distancia: 668.49
# Valor ofrecido por domicilio 2000.00
# Tiempo: 02:32:04: Domiciliario c1 asignado a la orden c18
# Tiempo de ida del domiciliario a la tienda: 0:00:37.872053
# Tiempo estimado del domiciliario al cliente: 0:01:44.633588 horas
# Tiempo estimado de entrega: 8.53 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:22.505641 horas
# Domiciliario c1 estará disponible a las 02:42:58
# Tiempo: 03:39:47: La Plataforma ha recibido la orden c19
# Tiempo: 03:39:47: La Plataforma ha informado a la tienda s3
# Distancia entre la tienda y el cliente: 4.87
# Costo según la distancia: 4867.94
# Valor ofrecido por domicilio 2000.00
# Tiempo: 03:39:47: Domiciliario c2 asignado a la orden c19
# Tiempo de ida del domiciliario a la tienda: 0:00:02.108912
# Tiempo estimado del domiciliario al cliente: 0:12:41.937756 horas
# Tiempo estimado de entrega: 21.3 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:12:44.046668 horas
# Domiciliario c2 estará disponible a las 04:13:49
# Tiempo: 06:24:20: La Plataforma ha recibido la orden c20
# Tiempo: 06:24:20: La Plataforma ha informado a la tienda s11
# Distancia entre la tienda y el cliente: 0.72
# Costo según la distancia: 721.47
# Valor ofrecido por domicilio 2000.00
# Tiempo: 06:24:20: Domiciliario c1 asignado a la orden c20
# Tiempo de ida del domiciliario a la tienda: 0:00:44.610549
# Tiempo estimado del domiciliario al cliente: 0:01:52.925758 horas
# Tiempo estimado de entrega: 26.68 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:37.536307 horas
# Domiciliario c1 estará disponible a las 06:53:38
# Tiempo: 07:23:42: La Plataforma ha recibido la orden c21
# Tiempo: 07:23:42: La Plataforma ha informado a la tienda s12
# Distancia entre la tienda y el cliente: 0.89
# Costo según la distancia: 893.40
# Valor ofrecido por domicilio 2000.00
# Tiempo: 07:23:42: Domiciliario c1 asignado a la orden c21
# Tiempo de ida del domiciliario a la tienda: 0:00:16.094357
# Tiempo estimado del domiciliario al cliente: 0:02:19.837206 horas
# Tiempo estimado de entrega: 20.45 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:35.931563 horas
# Domiciliario c1 estará disponible a las 07:46:44
# Tiempo: 07:27:52: La Plataforma ha recibido la orden c22
# Tiempo: 07:27:52: La Plataforma ha informado a la tienda s11
# Distancia entre la tienda y el cliente: 2.32
# Costo según la distancia: 2316.56
# Valor ofrecido por domicilio 2000.00
# Domiciliario c2 ha rechazado la orden c22. 1
# Valor ofrecido por domicilio 2231.66
# Domiciliario c3 ha rechazado la orden c22. 2
# Valor ofrecido por domicilio 2463.31
# Tiempo: 07:31:52: Domiciliario c6 asignado a la orden c22
# Tiempo de ida del domiciliario a la tienda: 0:00:12.751567
# Tiempo estimado del domiciliario al cliente: 0:06:02.592602 horas
# Tiempo estimado de entrega: 30.56 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:06:15.344169 horas
# Domiciliario c6 estará disponible a las 08:08:40
# Tiempo: 07:28:13: La Plataforma ha recibido la orden c23
# Tiempo: 07:28:13: La Plataforma ha informado a la tienda s12
# Distancia entre la tienda y el cliente: 2.77
# Costo según la distancia: 2766.73
# Valor ofrecido por domicilio 2000.00
# Domiciliario c2 ha rechazado la orden c23. 1
# Valor ofrecido por domicilio 2276.67
# Domiciliario c3 ha rechazado la orden c23. 2
# Valor ofrecido por domicilio 2553.35
# Domiciliario c4 ha rechazado la orden c23. 3
# Valor ofrecido por domicilio 2830.02
# Tiempo: 07:34:13: Domiciliario c7 asignado a la orden c23
# Tiempo de ida del domiciliario a la tienda: 0:00:02.472172
# Tiempo estimado del domiciliario al cliente: 0:07:13.053635 horas
# Tiempo estimado de entrega: 35.54 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:07:15.525807 horas
# Domiciliario c7 estará disponible a las 08:17:00
# Tiempo: 07:36:20: La Plataforma ha recibido la orden c24
# Tiempo: 07:36:20: La Plataforma ha informado a la tienda s13
# Distancia entre la tienda y el cliente: 1.34
# Costo según la distancia: 1339.32
# Valor ofrecido por domicilio 2000.00
# Tiempo: 07:36:20: Domiciliario c3 asignado a la orden c24
# Tiempo de ida del domiciliario a la tienda: 0:00:19.257541
# Tiempo estimado del domiciliario al cliente: 0:06:41.794605 horas
# Tiempo estimado de entrega: 19.97 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:07:01.052146 horas
# Domiciliario c3 estará disponible a las 08:03:19
# Tiempo: 07:36:37: La Plataforma ha recibido la orden c25
# Tiempo: 07:36:37: La Plataforma ha informado a la tienda s12
# Distancia entre la tienda y el cliente: 0.77
# Costo según la distancia: 769.26
# Valor ofrecido por domicilio 2000.00
# Domiciliario c2 ha rechazado la orden c25. 1
# Valor ofrecido por domicilio 2076.93
# Domiciliario c9 ha rechazado la orden c25. 2
# Valor ofrecido por domicilio 2153.85
# Tiempo: 07:40:37: Domiciliario c11 asignado a la orden c25
# Tiempo de ida del domiciliario a la tienda: 0:00:26.036450
# Tiempo estimado del domiciliario al cliente: 0:02:00.405523 horas
# Tiempo estimado de entrega: 30.79 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:26.441973 horas
# Domiciliario c11 estará disponible a las 08:13:50
# Tiempo: 07:36:37: La Plataforma ha recibido la orden c26
# Tiempo: 07:36:37: La Plataforma ha informado a la tienda s14
# Distancia entre la tienda y el cliente: 3.65
# Costo según la distancia: 3649.87
# Valor ofrecido por domicilio 2000.00
# Domiciliario c2 ha rechazado la orden c26. 1
# Valor ofrecido por domicilio 2364.99
# Domiciliario c9 ha rechazado la orden c26. 2
# Valor ofrecido por domicilio 2729.97
# Domiciliario c12 ha rechazado la orden c26. 3
# Valor ofrecido por domicilio 3094.96
# Domiciliario c13 ha rechazado la orden c26. 4
# Valor ofrecido por domicilio 3459.95
# Domiciliario c14 ha rechazado la orden c26. 5
# Valor ofrecido por domicilio 3824.93
# Orden c26 rechazada definitivamente.
# Tiempo: 07:36:37: La Plataforma ha recibido la orden c27
# Tiempo: 07:36:37: La Plataforma ha informado a la tienda s15
# Distancia entre la tienda y el cliente: 0.76
# Costo según la distancia: 756.88
# Valor ofrecido por domicilio 2000.00
# Tiempo: 07:36:37: Domiciliario c2 asignado a la orden c27
# Tiempo de ida del domiciliario a la tienda: 0:00:26.036450
# Tiempo estimado del domiciliario al cliente: 0:01:58.467704 horas
# Tiempo estimado de entrega: 37.66 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:24.504154 horas
# Domiciliario c2 estará disponible a las 08:16:41
# Tiempo: 07:53:56: La Plataforma ha recibido la orden c28
# Tiempo: 07:53:56: La Plataforma ha informado a la tienda s16
# Distancia entre la tienda y el cliente: 2.77
# Costo según la distancia: 2768.75
# Valor ofrecido por domicilio 2000.00
# Domiciliario c4 ha rechazado la orden c28. 1
# Valor ofrecido por domicilio 2276.88
# Domiciliario c10 ha rechazado la orden c28. 2
# Valor ofrecido por domicilio 2553.75
# Domiciliario c12 ha rechazado la orden c28. 3
# Valor ofrecido por domicilio 2830.63
# Tiempo: 07:59:56: Domiciliario c13 asignado a la orden c28
# Tiempo de ida del domiciliario a la tienda: 0:00:08.930640
# Tiempo estimado del domiciliario al cliente: 0:07:13.369638 horas
# Tiempo estimado de entrega: 32.72 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:07:22.300278 horas
# Domiciliario c13 estará disponible a las 08:40:01
# Tiempo: 07:55:58: La Plataforma ha recibido la orden c29
# Tiempo: 07:55:58: La Plataforma ha informado a la tienda s12
# Distancia entre la tienda y el cliente: 4.25
# Costo según la distancia: 4250.12
# Valor ofrecido por domicilio 2000.00
# Tiempo: 07:55:58: Domiciliario c1 asignado a la orden c29
# Tiempo de ida del domiciliario a la tienda: 0:00:06.883016
# Tiempo estimado del domiciliario al cliente: 0:11:05.236879 horas
# Tiempo estimado de entrega: 39.09 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:11:12.119895 horas
# Domiciliario c1 estará disponible a las 08:46:15
# Tiempo: 07:59:16: La Plataforma ha recibido la orden c30
# Tiempo: 07:59:16: La Plataforma ha informado a la tienda s16
# Distancia entre la tienda y el cliente: 1.12
# Costo según la distancia: 1115.37
# Valor ofrecido por domicilio 2000.00
# Domiciliario c4 ha rechazado la orden c30. 1
# Valor ofrecido por domicilio 2111.54
# Domiciliario c10 ha rechazado la orden c30. 2
# Valor ofrecido por domicilio 2223.07
# Tiempo: 08:03:16: Domiciliario c12 asignado a la orden c30
# Tiempo de ida del domiciliario a la tienda: 0:00:05.051351
# Tiempo estimado del domiciliario al cliente: 0:13:23.069264 horas
# Tiempo estimado de entrega: 53.39 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:13:28.120615 horas
# Domiciliario c12 estará disponible a las 09:10:07
# Tiempo: 08:02:17: La Plataforma ha recibido la orden c34
# Tiempo: 08:02:17: La Plataforma ha informado a la tienda s16
# Distancia entre la tienda y el cliente: 3.30
# Costo según la distancia: 3302.68
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:02:17: Domiciliario c4 asignado a la orden c34
# Tiempo de ida del domiciliario a la tienda: 0:00:06.752861
# Tiempo estimado del domiciliario al cliente: 0:08:36.941615 horas
# Tiempo estimado de entrega: 44.33 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:08:43.694476 horas
# Domiciliario c4 estará disponible a las 08:55:20
# Tiempo: 08:02:22: La Plataforma ha recibido la orden c35
# Tiempo: 08:02:22: La Plataforma ha informado a la tienda s14
# Distancia entre la tienda y el cliente: 4.57
# Costo según la distancia: 4566.34
# Valor ofrecido por domicilio 2000.00
# Domiciliario c9 ha rechazado la orden c35. 1
# Valor ofrecido por domicilio 2456.63
# Domiciliario c14 ha rechazado la orden c35. 2
# Valor ofrecido por domicilio 2913.27
# Tiempo: 08:06:22: Domiciliario c15 asignado a la orden c35
# Tiempo de ida del domiciliario a la tienda: 0:00:12.215359
# Tiempo estimado del domiciliario al cliente: 0:11:54.731556 horas
# Tiempo estimado de entrega: 33.4 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:12:06.946915 horas
# Domiciliario c15 estará disponible a las 08:51:52
# Tiempo: 08:10:19: La Plataforma ha recibido la orden c36
# Tiempo: 08:10:19: La Plataforma ha informado a la tienda s17
# Distancia entre la tienda y el cliente: 0.81
# Costo según la distancia: 809.09
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:10:19: Domiciliario c3 asignado a la orden c36
# Tiempo de ida del domiciliario a la tienda: 0:01:17.222817
# Tiempo estimado del domiciliario al cliente: 0:04:02.728157 horas
# Tiempo estimado de entrega: 20.33 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:05:19.950974 horas
# Domiciliario c3 estará disponible a las 08:35:58
# Tiempo: 08:13:19: La Plataforma ha recibido la orden c37
# Tiempo: 08:13:19: La Plataforma ha informado a la tienda s18
# Distancia entre la tienda y el cliente: 2.30
# Costo según la distancia: 2301.95
# Valor ofrecido por domicilio 2000.00
# Domiciliario c6 ha rechazado la orden c37. 1
# Valor ofrecido por domicilio 2230.19
# Domiciliario c9 ha rechazado la orden c37. 2
# Valor ofrecido por domicilio 2460.39
# Tiempo: 08:17:19: Domiciliario c14 asignado a la orden c37
# Tiempo de ida del domiciliario a la tienda: 0:00:05.733670
# Tiempo estimado del domiciliario al cliente: 0:06:00.305044 horas
# Tiempo estimado de entrega: 27.23 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:06:06.038714 horas
# Domiciliario c14 estará disponible a las 08:50:38
# Tiempo: 08:13:39: La Plataforma ha recibido la orden c38
# Tiempo: 08:13:39: La Plataforma ha informado a la tienda s19
# Distancia entre la tienda y el cliente: 2.16
# Costo según la distancia: 2157.75
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:13:39: Domiciliario c6 asignado a la orden c38
# Tiempo de ida del domiciliario a la tienda: 0:00:43.958459
# Tiempo estimado del domiciliario al cliente: 0:05:37.735239 horas
# Tiempo estimado de entrega: 19.93 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:06:21.693698 horas
# Domiciliario c6 estará disponible a las 08:39:56
# Tiempo: 08:14:05: La Plataforma ha recibido la orden c39
# Tiempo: 08:14:05: La Plataforma ha informado a la tienda s15
# Distancia entre la tienda y el cliente: 0.98
# Costo según la distancia: 975.85
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:14:05: Domiciliario c9 asignado a la orden c39
# Tiempo de ida del domiciliario a la tienda: 0:02:16.062104
# Tiempo estimado del domiciliario al cliente: 0:11:42.612467 horas
# Tiempo estimado de entrega: 48.06 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:13:58.674571 horas
# Domiciliario c9 estará disponible a las 09:16:07
# Tiempo: 08:16:30: La Plataforma ha recibido la orden c40
# Tiempo: 08:16:30: La Plataforma ha informado a la tienda s17
# Distancia entre la tienda y el cliente: 0.38
# Costo según la distancia: 383.26
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:16:30: Domiciliario c11 asignado a la orden c40
# Tiempo de ida del domiciliario a la tienda: 0:00:27.133911
# Tiempo estimado del domiciliario al cliente: 0:00:59.988523 horas
# Tiempo estimado de entrega: 26.64 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:01:27.122434 horas
# Domiciliario c11 estará disponible a las 08:44:35
# Tiempo: 08:19:17: La Plataforma ha recibido la orden c41
# Tiempo: 08:19:17: La Plataforma ha informado a la tienda s20
# Distancia entre la tienda y el cliente: 1.23
# Costo según la distancia: 1225.13
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:19:17: Domiciliario c7 asignado a la orden c41
# Tiempo de ida del domiciliario a la tienda: 0:00:01.582583
# Tiempo estimado del domiciliario al cliente: 0:03:11.758828 horas
# Tiempo estimado de entrega: 19.89 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:03:13.341411 horas
# Domiciliario c7 estará disponible a las 08:42:23
# Tiempo: 08:20:52: La Plataforma ha recibido la orden c42
# Tiempo: 08:20:52: La Plataforma ha informado a la tienda s21
# Distancia entre la tienda y el cliente: 1.40
# Costo según la distancia: 1402.28
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:20:52: Domiciliario c2 asignado a la orden c42
# Tiempo de ida del domiciliario a la tienda: 0:00:18.726161
# Tiempo estimado del domiciliario al cliente: 0:03:39.487065 horas
# Tiempo estimado de entrega: 23.52 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:03:58.213226 horas
# Domiciliario c2 estará disponible a las 08:48:21
# Tiempo: 08:22:18: La Plataforma ha recibido la orden c43
# Tiempo: 08:22:18: La Plataforma ha informado a la tienda s13
# Distancia entre la tienda y el cliente: 0.60
# Costo según la distancia: 597.58
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:22:18: Domiciliario c17 asignado a la orden c43
# Tiempo de ida del domiciliario a la tienda: 0:00:09.735514
# Tiempo estimado del domiciliario al cliente: 0:01:33.533480 horas
# Tiempo estimado de entrega: 12.67 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:01:43.268994 horas
# Domiciliario c17 estará disponible a las 08:36:41
# Tiempo: 08:22:19: La Plataforma ha recibido la orden c44
# Tiempo: 08:22:19: La Plataforma ha informado a la tienda s16
# Distancia entre la tienda y el cliente: 2.89
# Costo según la distancia: 2886.30
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:22:19: Domiciliario c10 asignado a la orden c44
# Tiempo de ida del domiciliario a la tienda: 0:05:16.682711
# Tiempo estimado del domiciliario al cliente: 0:07:31.767934 horas
# Tiempo estimado de entrega: 43.92 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:12:48.450645 horas
# Domiciliario c10 estará disponible a las 09:19:02
# Tiempo: 08:26:11: La Plataforma ha recibido la orden c45
# Tiempo: 08:26:11: La Plataforma ha informado a la tienda s22
# Distancia entre la tienda y el cliente: 2.63
# Costo según la distancia: 2630.90
# Valor ofrecido por domicilio 2000.00
# Domiciliario c19 ha rechazado la orden c45. 1
# Valor ofrecido por domicilio 2263.09
# Tiempo: 08:28:11: Domiciliario c20 asignado a la orden c45
# Tiempo de ida del domiciliario a la tienda: 0:00:31.843237
# Tiempo estimado del domiciliario al cliente: 0:06:51.792676 horas
# Tiempo estimado de entrega: 49.76 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:07:23.635913 horas
# Domiciliario c20 estará disponible a las 09:25:20
# Tiempo: 08:27:57: La Plataforma ha recibido la orden c46
# Tiempo: 08:27:57: La Plataforma ha informado a la tienda s19
# Distancia entre la tienda y el cliente: 0.86
# Costo según la distancia: 863.32
# Valor ofrecido por domicilio 2000.00
# Domiciliario c19 ha rechazado la orden c46. 1
# Valor ofrecido por domicilio 2086.33
# Tiempo: 08:29:57: Domiciliario c21 asignado a la orden c46
# Tiempo de ida del domiciliario a la tienda: 0:00:19.374009
# Tiempo estimado del domiciliario al cliente: 0:02:15.127753 horas
# Tiempo estimado de entrega: 16.14 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:34.501762 horas
# Domiciliario c21 estará disponible a las 08:48:39
# Tiempo: 08:30:17: La Plataforma ha recibido la orden c47
# Tiempo: 08:30:17: La Plataforma ha informado a la tienda s20
# Distancia entre la tienda y el cliente: 2.85
# Costo según la distancia: 2850.87
# Valor ofrecido por domicilio 2000.00
# Domiciliario c19 ha rechazado la orden c47. 1
# Valor ofrecido por domicilio 2285.09
# Tiempo: 08:32:17: Domiciliario c22 asignado a la orden c47
# Tiempo de ida del domiciliario a la tienda: 0:00:13.843976
# Tiempo estimado del domiciliario al cliente: 0:07:26.223755 horas
# Tiempo estimado de entrega: 24.03 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:07:40.067731 horas
# Domiciliario c22 estará disponible a las 09:03:58
# Tiempo: 08:31:10: La Plataforma ha recibido la orden c48
# Tiempo: 08:31:10: La Plataforma ha informado a la tienda s22
# Distancia entre la tienda y el cliente: 2.98
# Costo según la distancia: 2984.46
# Valor ofrecido por domicilio 2000.00
# Domiciliario c16 ha rechazado la orden c48. 1
# Valor ofrecido por domicilio 2298.45
# Tiempo: 08:33:10: Domiciliario c19 asignado a la orden c48
# Tiempo de ida del domiciliario a la tienda: 0:00:09.580781
# Tiempo estimado del domiciliario al cliente: 0:14:55.338427 horas
# Tiempo estimado de entrega: 55.3 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:15:04.919208 horas
# Domiciliario c19 estará disponible a las 09:43:32
# Tiempo: 08:31:31: La Plataforma ha recibido la orden c49
# Tiempo: 08:31:31: La Plataforma ha informado a la tienda s23
# Distancia entre la tienda y el cliente: 1.64
# Costo según la distancia: 1637.96
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:31:31: Domiciliario c28 asignado a la orden c49
# Tiempo de ida del domiciliario a la tienda: 0:00:11.869832
# Tiempo estimado del domiciliario al cliente: 0:08:11.388414 horas
# Tiempo estimado de entrega: 29.64 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:08:23.258246 horas
# Domiciliario c28 estará disponible a las 09:09:32
# Tiempo: 08:33:36: La Plataforma ha recibido la orden c50
# Tiempo: 08:33:36: La Plataforma ha informado a la tienda s20
# Distancia entre la tienda y el cliente: 0.63
# Costo según la distancia: 629.74
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:33:36: Domiciliario c29 asignado a la orden c50
# Tiempo de ida del domiciliario a la tienda: 0:00:09.991385
# Tiempo estimado del domiciliario al cliente: 0:01:38.567252 horas
# Tiempo estimado de entrega: 18.28 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:01:48.558637 horas
# Domiciliario c29 estará disponible a las 08:53:41
# Tiempo: 08:35:17: La Plataforma ha recibido la orden c51
# Tiempo: 08:35:17: La Plataforma ha informado a la tienda s24
# Distancia entre la tienda y el cliente: 1.20
# Costo según la distancia: 1202.92
# Valor ofrecido por domicilio 2000.00
# Domiciliario c27 ha rechazado la orden c51. 1
# Valor ofrecido por domicilio 2120.29
# Tiempo: 08:37:17: Domiciliario c31 asignado a la orden c51
# Tiempo de ida del domiciliario a la tienda: 0:00:50.878484
# Tiempo estimado del domiciliario al cliente: 0:03:08.282811 horas
# Tiempo estimado de entrega: 24.99 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:03:59.161295 horas
# Domiciliario c31 estará disponible a las 09:06:15
# Tiempo: 08:37:23: La Plataforma ha recibido la orden c52
# Tiempo: 08:37:23: La Plataforma ha informado a la tienda s13
# Distancia entre la tienda y el cliente: 0.41
# Costo según la distancia: 409.96
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:37:23: Domiciliario c3 asignado a la orden c52
# Tiempo de ida del domiciliario a la tienda: 0:00:26.846968
# Tiempo estimado del domiciliario al cliente: 0:02:02.986993 horas
# Tiempo estimado de entrega: 13.33 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:29.833961 horas
# Domiciliario c3 estará disponible a las 08:53:12
# Tiempo: 08:43:41: La Plataforma ha recibido la orden c53
# Tiempo: 08:43:41: La Plataforma ha informado a la tienda s25
# Distancia entre la tienda y el cliente: 1.64
# Costo según la distancia: 1638.70
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:43:41: Domiciliario c6 asignado a la orden c53
# Tiempo de ida del domiciliario a la tienda: 0:00:01.438690
# Tiempo estimado del domiciliario al cliente: 0:04:16.492138 horas
# Tiempo estimado de entrega: 11.22 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:04:17.930828 horas
# Domiciliario c6 estará disponible a las 08:59:12
# Tiempo: 08:44:06: La Plataforma ha recibido la orden c54
# Tiempo: 08:44:06: La Plataforma ha informado a la tienda s11
# Distancia entre la tienda y el cliente: 1.24
# Costo según la distancia: 1235.71
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:44:06: Domiciliario c7 asignado a la orden c54
# Tiempo de ida del domiciliario a la tienda: 0:00:30.157881
# Tiempo estimado del domiciliario al cliente: 0:03:13.415100 horas
# Tiempo estimado de entrega: 17.94 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:03:43.572981 horas
# Domiciliario c7 estará disponible a las 09:05:45
# Tiempo: 08:44:46: La Plataforma ha recibido la orden c55
# Tiempo: 08:44:46: La Plataforma ha informado a la tienda s26
# Distancia entre la tienda y el cliente: 0.93
# Costo según la distancia: 930.99
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:44:46: Domiciliario c11 asignado a la orden c55
# Tiempo de ida del domiciliario a la tienda: 0:00:11.663302
# Tiempo estimado del domiciliario al cliente: 0:02:25.720776 horas
# Tiempo estimado de entrega: 22.56 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:37.384078 horas
# Domiciliario c11 estará disponible a las 09:09:56
# Tiempo: 08:44:55: La Plataforma ha recibido la orden c56
# Tiempo: 08:44:55: La Plataforma ha informado a la tienda s13
# Distancia entre la tienda y el cliente: 0.96
# Costo según la distancia: 955.06
# Valor ofrecido por domicilio 2000.00
# Domiciliario c13 ha rechazado la orden c56. 1
# Valor ofrecido por domicilio 2095.51
# Domiciliario c17 ha rechazado la orden c56. 2
# Valor ofrecido por domicilio 2191.01
# Domiciliario c32 ha rechazado la orden c56. 3
# Valor ofrecido por domicilio 2286.52
# Tiempo: 08:50:55: Domiciliario c33 asignado a la orden c56
# Tiempo de ida del domiciliario a la tienda: 0:00:05.172586
# Tiempo estimado del domiciliario al cliente: 0:02:29.486874 horas
# Tiempo estimado de entrega: 13.73 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:34.659460 horas
# Domiciliario c33 estará disponible a las 09:07:13
# Tiempo: 08:45:19: La Plataforma ha recibido la orden c57
# Tiempo: 08:45:19: La Plataforma ha informado a la tienda s12
# Distancia entre la tienda y el cliente: 1.33
# Costo según la distancia: 1334.65
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:45:19: Domiciliario c13 asignado a la orden c57
# Tiempo de ida del domiciliario a la tienda: 0:01:16.210523
# Tiempo estimado del domiciliario al cliente: 0:03:28.901999 horas
# Tiempo estimado de entrega: 34.17 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:04:45.112522 horas
# Domiciliario c13 estará disponible a las 09:24:14
# Tiempo: 08:45:57: La Plataforma ha recibido la orden c58
# Tiempo: 08:45:57: La Plataforma ha informado a la tienda s22
# Distancia entre la tienda y el cliente: 0.45
# Costo según la distancia: 454.62
# Valor ofrecido por domicilio 2000.00
# Domiciliario c16 ha rechazado la orden c58. 1
# Valor ofrecido por domicilio 2045.46
# Tiempo: 08:47:57: Domiciliario c17 asignado a la orden c58
# Tiempo de ida del domiciliario a la tienda: 0:00:20.742667
# Tiempo estimado del domiciliario al cliente: 0:01:11.158622 horas
# Tiempo estimado de entrega: 18.47 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:01:31.901289 horas
# Domiciliario c17 estará disponible a las 09:07:57
# Tiempo: 08:48:43: La Plataforma ha recibido la orden c59
# Tiempo: 08:48:43: La Plataforma ha informado a la tienda s12
# Distancia entre la tienda y el cliente: 0.71
# Costo según la distancia: 707.16
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:48:43: Domiciliario c1 asignado a la orden c59
# Tiempo de ida del domiciliario a la tienda: 0:00:42.692961
# Tiempo estimado del domiciliario al cliente: 0:01:50.685234 horas
# Tiempo estimado de entrega: 31.99 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:33.378195 horas
# Domiciliario c1 estará disponible a las 09:23:15
# Tiempo: 08:50:29: La Plataforma ha recibido la orden c60
# Tiempo: 08:50:29: La Plataforma ha informado a la tienda s12
# Distancia entre la tienda y el cliente: 0.67
# Costo según la distancia: 673.24
# Valor ofrecido por domicilio 2000.00
# Domiciliario c21 ha rechazado la orden c60. 1
# Valor ofrecido por domicilio 2067.32
# Tiempo: 08:52:29: Domiciliario c32 asignado a la orden c60
# Tiempo de ida del domiciliario a la tienda: 0:00:40.078770
# Tiempo estimado del domiciliario al cliente: 0:01:45.377002 horas
# Tiempo estimado de entrega: 31.37 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:25.455772 horas
# Domiciliario c32 estará disponible a las 09:26:16
# Tiempo: 08:56:01: La Plataforma ha recibido la orden c61
# Tiempo: 08:56:01: La Plataforma ha informado a la tienda s23
# Distancia entre la tienda y el cliente: 0.54
# Costo según la distancia: 539.79
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:56:01: Domiciliario c3 asignado a la orden c61
# Tiempo de ida del domiciliario a la tienda: 0:00:22.354662
# Tiempo estimado del domiciliario al cliente: 0:02:41.935902 horas
# Tiempo estimado de entrega: 8.9 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:03:04.290564 horas
# Domiciliario c3 estará disponible a las 09:07:59
# Tiempo: 08:57:18: La Plataforma ha recibido la orden c62
# Tiempo: 08:57:18: La Plataforma ha informado a la tienda s13
# Distancia entre la tienda y el cliente: 2.95
# Costo según la distancia: 2953.24
# Valor ofrecido por domicilio 2000.00
# Domiciliario c2 ha rechazado la orden c62. 1
# Valor ofrecido por domicilio 2295.32
# Tiempo: 08:59:18: Domiciliario c4 asignado a la orden c62
# Tiempo de ida del domiciliario a la tienda: 0:00:11.785111
# Tiempo estimado del domiciliario al cliente: 0:07:42.246617 horas
# Tiempo estimado de entrega: 18.8 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:07:54.031728 horas
# Domiciliario c4 estará disponible a las 09:26:00
# Tiempo: 08:57:25: La Plataforma ha recibido la orden c63
# Tiempo: 08:57:25: La Plataforma ha informado a la tienda s16
# Distancia entre la tienda y el cliente: 0.59
# Costo según la distancia: 585.82
# Valor ofrecido por domicilio 2000.00
# Tiempo: 08:57:25: Domiciliario c2 asignado a la orden c63
# Tiempo de ida del domiciliario a la tienda: 0:00:45.664282
# Tiempo estimado del domiciliario al cliente: 0:01:31.693065 horas
# Tiempo estimado de entrega: 27.56 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:17.357347 horas
# Domiciliario c2 estará disponible a las 09:27:15
# Tiempo: 08:58:07: La Plataforma ha recibido la orden c64
# Tiempo: 08:58:07: La Plataforma ha informado a la tienda s12
# Distancia entre la tienda y el cliente: 3.14
# Costo según la distancia: 3139.32
# Valor ofrecido por domicilio 2000.00
# Domiciliario c14 ha rechazado la orden c64. 1
# Valor ofrecido por domicilio 2313.93
# Domiciliario c15 ha rechazado la orden c64. 2
# Valor ofrecido por domicilio 2627.86
# Tiempo: 09:02:07: Domiciliario c16 asignado a la orden c64
# Tiempo de ida del domiciliario a la tienda: 0:00:18.539778
# Tiempo estimado del domiciliario al cliente: 0:08:11.372547 horas
# Tiempo estimado de entrega: 42.45 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:08:29.912325 horas
# Domiciliario c16 estará disponible a las 09:53:03
# Tiempo: 09:00:25: La Plataforma ha recibido la orden c70
# Tiempo: 09:00:25: La Plataforma ha informado a la tienda s27
# Distancia entre la tienda y el cliente: 0.56
# Costo según la distancia: 558.65
# Valor ofrecido por domicilio 2000.00
# Tiempo: 09:00:25: Domiciliario c6 asignado a la orden c70
# Tiempo de ida del domiciliario a la tienda: 0:00:14.377656
# Tiempo estimado del domiciliario al cliente: 0:01:27.440463 horas
# Tiempo estimado de entrega: 22.61 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:01:41.818119 horas
# Domiciliario c6 estará disponible a las 09:24:43
# Tiempo: 09:00:54: La Plataforma ha recibido la orden c71
# Tiempo: 09:00:54: La Plataforma ha informado a la tienda s28
# Distancia entre la tienda y el cliente: 2.01
# Costo según la distancia: 2008.80
# Valor ofrecido por domicilio 2000.00
# Domiciliario c8 ha rechazado la orden c71. 1
# Valor ofrecido por domicilio 2200.88
# Tiempo: 09:02:54: Domiciliario c14 asignado a la orden c71
# Tiempo de ida del domiciliario a la tienda: 0:00:06.051992
# Tiempo estimado del domiciliario al cliente: 0:05:14.421311 horas
# Tiempo estimado de entrega: 16.54 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:05:20.473303 horas
# Domiciliario c14 estará disponible a las 09:24:46
# Tiempo: 09:03:45: La Plataforma ha recibido la orden c72
# Tiempo: 09:03:45: La Plataforma ha informado a la tienda s12
# Distancia entre la tienda y el cliente: 0.58
# Costo según la distancia: 580.51
# Valor ofrecido por domicilio 2000.00
# Tiempo: 09:03:45: Domiciliario c15 asignado a la orden c72
# Tiempo de ida del domiciliario a la tienda: 0:00:24.263280
# Tiempo estimado del domiciliario al cliente: 0:01:30.863062 horas
# Tiempo estimado de entrega: 41.19 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:01:55.126342 horas
# Domiciliario c15 estará disponible a las 09:46:51
# Tiempo: 09:04:27: La Plataforma ha recibido la orden c73
# Tiempo: 09:04:27: La Plataforma ha informado a la tienda s19
# Distancia entre la tienda y el cliente: 2.98
# Costo según la distancia: 2983.28
# Valor ofrecido por domicilio 2000.00
# Domiciliario c21 ha rechazado la orden c73. 1
# Valor ofrecido por domicilio 2298.33
# Domiciliario c22 ha rechazado la orden c73. 2
# Valor ofrecido por domicilio 2596.66
# Tiempo: 09:08:27: Domiciliario c23 asignado a la orden c73
# Tiempo de ida del domiciliario a la tienda: 0:00:18.539778
# Tiempo estimado del domiciliario al cliente: 0:07:46.948922 horas
# Tiempo estimado de entrega: 21.67 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:08:05.488700 horas
# Domiciliario c23 estará disponible a las 09:38:12
# Tiempo: 09:04:59: La Plataforma ha recibido la orden c74
# Tiempo: 09:04:59: La Plataforma ha informado a la tienda s20
# Distancia entre la tienda y el cliente: 0.70
# Costo según la distancia: 700.93
# Valor ofrecido por domicilio 2000.00
# Tiempo: 09:04:59: Domiciliario c21 asignado a la orden c74
# Tiempo de ida del domiciliario a la tienda: 0:00:18.080414
# Tiempo estimado del domiciliario al cliente: 0:01:49.710761 horas
# Tiempo estimado de entrega: 18.93 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:07.791175 horas
# Domiciliario c21 estará disponible a las 09:26:02
# Tiempo: 09:10:48: La Plataforma ha recibido la orden c75
# Tiempo: 09:10:48: La Plataforma ha informado a la tienda s29
# Distancia entre la tienda y el cliente: 2.73
# Costo según la distancia: 2726.96
# Valor ofrecido por domicilio 2000.00
# Tiempo: 09:10:48: Domiciliario c3 asignado a la orden c75
# Tiempo de ida del domiciliario a la tienda: 0:00:19.939785
# Tiempo estimado del domiciliario al cliente: 0:13:38.088473 horas
# Tiempo estimado de entrega: 46.07 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:13:58.028258 horas
# Domiciliario c3 estará disponible a las 10:10:50
# Tiempo: 09:12:17: La Plataforma ha recibido la orden c76
# Tiempo: 09:12:17: La Plataforma ha informado a la tienda s11
# Distancia entre la tienda y el cliente: 1.61
# Costo según la distancia: 1606.88
# Valor ofrecido por domicilio 2000.00
# Tiempo: 09:12:17: Domiciliario c7 asignado a la orden c76
# Tiempo de ida del domiciliario a la tienda: 0:00:11.018481
# Tiempo estimado del domiciliario al cliente: 0:04:11.511785 horas
# Tiempo estimado de entrega: 23.41 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:04:22.530266 horas
# Domiciliario c7 estará disponible a las 09:40:04
# Tiempo: 09:13:59: La Plataforma ha recibido la orden c77
# Tiempo: 09:13:59: La Plataforma ha informado a la tienda s17
# Distancia entre la tienda y el cliente: 0.59
# Costo según la distancia: 593.95
# Valor ofrecido por domicilio 2000.00
# Tiempo: 09:13:59: Domiciliario c11 asignado a la orden c77
# Tiempo de ida del domiciliario a la tienda: 0:00:16.227164
# Tiempo estimado del domiciliario al cliente: 0:01:32.966571 horas
# Tiempo estimado de entrega: 26.67 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:01:49.193735 horas
# Domiciliario c11 estará disponible a las 09:42:28
# Tiempo: 09:14:20: La Plataforma ha recibido la orden c78
# Tiempo: 09:14:20: La Plataforma ha informado a la tienda s20
# Distancia entre la tienda y el cliente: 0.59
# Costo según la distancia: 588.86
# Valor ofrecido por domicilio 2000.00
# Tiempo: 09:14:20: Domiciliario c12 asignado a la orden c78
# Tiempo de ida del domiciliario a la tienda: 0:01:09.415520
# Tiempo estimado del domiciliario al cliente: 0:07:03.977846 horas
# Tiempo estimado de entrega: 25.32 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:08:13.393366 horas
# Domiciliario c12 estará disponible a las 09:47:52
# Tiempo: 09:16:21: La Plataforma ha recibido la orden c79
# Tiempo: 09:16:21: La Plataforma ha informado a la tienda s30
# Distancia entre la tienda y el cliente: 1.92
# Costo según la distancia: 1916.26
# Valor ofrecido por domicilio 2000.00
# Tiempo: 09:16:21: Domiciliario c9 asignado a la orden c79
# Tiempo de ida del domiciliario a la tienda: 0:00:55.944061
# Tiempo estimado del domiciliario al cliente: 0:22:59.704534 horas
# Tiempo estimado de entrega: 51.44 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:23:55.648595 horas
# Domiciliario c9 estará disponible a las 10:31:43
# Tiempo: 09:19:25: La Plataforma ha recibido la orden c80
# Tiempo: 09:19:25: La Plataforma ha informado a la tienda s20
# Distancia entre la tienda y el cliente: 1.19
# Costo según la distancia: 1187.00
# Valor ofrecido por domicilio 2000.00
# Domiciliario c10 ha rechazado la orden c80. 1
# Valor ofrecido por domicilio 2118.70
# Tiempo: 09:21:25: Domiciliario c17 asignado a la orden c80
# Tiempo de ida del domiciliario a la tienda: 0:00:01.307770
# Tiempo estimado del domiciliario al cliente: 0:03:05.791928 horas
# Tiempo estimado de entrega: 19.8 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:03:07.099698 horas
# Domiciliario c17 estará disponible a las 09:44:20
# Tiempo: 09:20:22: La Plataforma ha recibido la orden c81
# Tiempo: 09:20:22: La Plataforma ha informado a la tienda s31
# Distancia entre la tienda y el cliente: 0.76
# Costo según la distancia: 764.28
# Valor ofrecido por domicilio 2000.00
# Tiempo: 09:20:22: Domiciliario c27 asignado a la orden c81
# Tiempo de ida del domiciliario a la tienda: 0:00:25.038715
# Tiempo estimado del domiciliario al cliente: 0:01:59.626584 horas
# Tiempo estimado de entrega: 53.91 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:24.665299 horas
# Domiciliario c27 estará disponible a las 10:16:41
# Tiempo: 09:21:22: La Plataforma ha recibido la orden c82
# Tiempo: 09:21:22: La Plataforma ha informado a la tienda s20
# Distancia entre la tienda y el cliente: 0.92
# Costo según la distancia: 918.04
# Valor ofrecido por domicilio 2000.00
# Tiempo: 09:21:22: Domiciliario c28 asignado a la orden c82
# Tiempo de ida del domiciliario a la tienda: 0:00:17.254034
# Tiempo estimado del domiciliario al cliente: 0:04:35.411661 horas
# Tiempo estimado de entrega: 21.54 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:04:52.665695 horas
# Domiciliario c28 estará disponible a las 09:47:47
# Tiempo: 09:21:54: La Plataforma ha recibido la orden c83
# Tiempo: 09:21:54: La Plataforma ha informado a la tienda s17
# Distancia entre la tienda y el cliente: 3.09
# Costo según la distancia: 3090.19
# Valor ofrecido por domicilio 2000.00
# Domiciliario c10 ha rechazado la orden c83. 1
# Valor ofrecido por domicilio 2309.02
# Tiempo: 09:23:54: Domiciliario c22 asignado a la orden c83
# Tiempo de ida del domiciliario a la tienda: 0:00:11.559839
# ...
# Tiempo: 22:31:14: La Plataforma ha recibido la orden c3017
# Tiempo: 22:31:14: La Plataforma ha informado a la tienda s1
# Distancia entre la tienda y el cliente: 6.02
# Costo según la distancia: 6016.56
# Valor ofrecido por domicilio 2000.00
# Domiciliario c6 ha rechazado la orden c3017. 1
# Valor ofrecido por domicilio 2601.66
# Domiciliario c7 ha rechazado la orden c3017. 2
# Valor ofrecido por domicilio 3203.31
# Tiempo: 22:35:14: Domiciliario c11 asignado a la orden c3017
# Tiempo de ida del domiciliario a la tienda: 0:00:05.318661
# Tiempo estimado del domiciliario al cliente: 0:15:41.723126 horas
# Tiempo estimado de entrega: 41.53 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:15:47.041787 horas
# Domiciliario c11 estará disponible a las 23:32:32
# Tiempo: 22:31:16: La Plataforma ha recibido la orden c3018
# Tiempo: 22:31:16: La Plataforma ha informado a la tienda s4
# Distancia entre la tienda y el cliente: 3.67
# Costo según la distancia: 3667.18
# Valor ofrecido por domicilio 2000.00
# Domiciliario c7 ha rechazado la orden c3018. 1
# Valor ofrecido por domicilio 2366.72
# Tiempo: 22:33:16: Domiciliario c8 asignado a la orden c3018
# Tiempo de ida del domiciliario a la tienda: 0:00:10.447232
# Tiempo estimado del domiciliario al cliente: 0:09:33.992805 horas
# Tiempo estimado de entrega: 35.57 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:09:44.440037 horas
# Domiciliario c8 estará disponible a las 23:18:34
# Tiempo: 22:32:03: La Plataforma ha recibido la orden c3019
# Tiempo: 22:32:03: La Plataforma ha informado a la tienda s306
# Distancia entre la tienda y el cliente: 0.92
# Costo según la distancia: 917.61
# Valor ofrecido por domicilio 2000.00
# Tiempo: 22:32:03: Domiciliario c6 asignado a la orden c3019
# Tiempo de ida del domiciliario a la tienda: 0:00:19.153562
# Tiempo estimado del domiciliario al cliente: 0:02:23.625140 horas
# Tiempo estimado de entrega: 38.65 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:42.778702 horas
# Domiciliario c6 estará disponible a las 23:13:24
# Tiempo: 22:32:31: La Plataforma ha recibido la orden c3020
# Tiempo: 22:32:31: La Plataforma ha informado a la tienda s3
# Distancia entre la tienda y el cliente: 2.12
# Costo según la distancia: 2116.92
# Valor ofrecido por domicilio 2000.00
# Tiempo: 22:32:31: Domiciliario c7 asignado a la orden c3020
# Tiempo de ida del domiciliario a la tienda: 0:00:18.911229
# Tiempo estimado del domiciliario al cliente: 0:05:31.344695 horas
# Tiempo estimado de entrega: 13.87 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:05:50.255924 horas
# Domiciliario c7 estará disponible a las 22:52:13
# Tiempo: 22:35:17: La Plataforma ha recibido la orden c3021
# Tiempo: 22:35:17: La Plataforma ha informado a la tienda s7
# Distancia entre la tienda y el cliente: 2.10
# Costo según la distancia: 2101.40
# Valor ofrecido por domicilio 2000.00
# Domiciliario c4 ha rechazado la orden c3021. 1
# Valor ofrecido por domicilio 2210.14
# Domiciliario c12 ha rechazado la orden c3021. 2
# Valor ofrecido por domicilio 2420.28
# Tiempo: 22:39:17: Domiciliario c14 asignado a la orden c3021
# Tiempo de ida del domiciliario a la tienda: 0:00:34.248579
# Tiempo estimado del domiciliario al cliente: 0:05:28.914286 horas
# Tiempo estimado de entrega: 46.99 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:06:03.162865 horas
# Domiciliario c14 estará disponible a las 23:32:19
# Tiempo: 22:37:47: La Plataforma ha recibido la orden c3022
# Tiempo: 22:37:47: La Plataforma ha informado a la tienda s116
# Distancia entre la tienda y el cliente: 0.80
# Costo según la distancia: 801.49
# Valor ofrecido por domicilio 2000.00
# Tiempo: 22:37:47: Domiciliario c12 asignado a la orden c3022
# Tiempo de ida del domiciliario a la tienda: 0:00:37.592380
# Tiempo estimado del domiciliario al cliente: 0:09:37.069984 horas
# Tiempo estimado de entrega: 33.54 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:10:14.662364 horas
# Domiciliario c12 estará disponible a las 23:21:34
# Tiempo: 22:50:02: La Plataforma ha recibido la orden c3023
# Tiempo: 22:50:02: La Plataforma ha informado a la tienda s231
# Distancia entre la tienda y el cliente: 4.19
# Costo según la distancia: 4189.92
# Valor ofrecido por domicilio 2000.00
# Domiciliario c2 ha rechazado la orden c3023. 1
# Valor ofrecido por domicilio 2418.99
# Domiciliario c4 ha rechazado la orden c3023. 2
# Valor ofrecido por domicilio 2837.98
# Domiciliario c13 ha rechazado la orden c3023. 3
# Valor ofrecido por domicilio 3256.98
# Domiciliario c15 ha rechazado la orden c3023. 4
# Valor ofrecido por domicilio 3675.97
# Domiciliario c17 ha rechazado la orden c3023. 5
# Valor ofrecido por domicilio 4094.96
# Orden c3023 rechazada definitivamente.
# Tiempo: 22:51:26: La Plataforma ha recibido la orden c3024
# Tiempo: 22:51:26: La Plataforma ha informado a la tienda s1
# Distancia entre la tienda y el cliente: 4.81
# Costo según la distancia: 4806.56
# Valor ofrecido por domicilio 2000.00
# Domiciliario c2 ha rechazado la orden c3024. 1
# Valor ofrecido por domicilio 2480.66
# Domiciliario c3 ha rechazado la orden c3024. 2
# Valor ofrecido por domicilio 2961.31
# Tiempo: 22:55:26: Domiciliario c10 asignado a la orden c3024
# Tiempo de ida del domiciliario a la tienda: 0:00:34.231948
# Tiempo estimado del domiciliario al cliente: 0:12:32.331736 horas
# Tiempo estimado de entrega: 28.88 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:13:06.563684 horas
# Domiciliario c10 estará disponible a las 23:37:25
# Tiempo: 22:51:29: La Plataforma ha recibido la orden c3025
# Tiempo: 22:51:29: La Plataforma ha informado a la tienda s4
# Distancia entre la tienda y el cliente: 1.67
# Costo según la distancia: 1668.96
# Valor ofrecido por domicilio 2000.00
# Tiempo: 22:51:29: Domiciliario c2 asignado a la orden c3025
# Tiempo de ida del domiciliario a la tienda: 0:00:09.033932
# Tiempo estimado del domiciliario al cliente: 0:04:21.228364 horas
# Tiempo estimado de entrega: 35.7 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:04:30.262296 horas
# Domiciliario c2 estará disponible a las 23:31:41
# Tiempo: 22:51:45: La Plataforma ha recibido la orden c3026
# Tiempo: 22:51:45: La Plataforma ha informado a la tienda s233
# Distancia entre la tienda y el cliente: 0.24
# Costo según la distancia: 239.33
# Valor ofrecido por domicilio 2000.00
# Tiempo: 22:51:45: Domiciliario c3 asignado a la orden c3026
# Tiempo de ida del domiciliario a la tienda: 0:00:09.914124
# Tiempo estimado del domiciliario al cliente: 0:01:11.799586 horas
# Tiempo estimado de entrega: 28.76 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:01:21.713710 horas
# Domiciliario c3 estará disponible a las 23:21:52
# Tiempo: 23:02:04: La Plataforma ha recibido la orden c3027
# Tiempo: 23:02:04: La Plataforma ha informado a la tienda s1
# Distancia entre la tienda y el cliente: 5.29
# Costo según la distancia: 5288.66
# Valor ofrecido por domicilio 2000.00
# Domiciliario c1 ha rechazado la orden c3027. 1
# Valor ofrecido por domicilio 2528.87
# Domiciliario c7 ha rechazado la orden c3027. 2
# Valor ofrecido por domicilio 3057.73
# Domiciliario c13 ha rechazado la orden c3027. 3
# Valor ofrecido por domicilio 3586.60
# Domiciliario c15 ha rechazado la orden c3027. 4
# Valor ofrecido por domicilio 4115.46
# Domiciliario c17 ha rechazado la orden c3027. 5
# Valor ofrecido por domicilio 4644.33
# Orden c3027 rechazada definitivamente.
# Tiempo: 23:03:34: La Plataforma ha recibido la orden c3028
# Tiempo: 23:03:34: La Plataforma ha informado a la tienda s1
# Distancia entre la tienda y el cliente: 5.40
# Costo según la distancia: 5399.63
# Valor ofrecido por domicilio 2000.00
# Domiciliario c1 ha rechazado la orden c3028. 1
# Valor ofrecido por domicilio 2539.96
# Domiciliario c7 ha rechazado la orden c3028. 2
# Valor ofrecido por domicilio 3079.93
# Domiciliario c13 ha rechazado la orden c3028. 3
# Valor ofrecido por domicilio 3619.89
# Tiempo: 23:09:34: Domiciliario c15 asignado a la orden c3028
# Tiempo de ida del domiciliario a la tienda: 0:00:30.213372
# Tiempo estimado del domiciliario al cliente: 0:14:05.159620 horas
# Tiempo estimado de entrega: 39.12 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:14:35.372992 horas
# Domiciliario c15 estará disponible a las 00:03:16
# Tiempo: 23:11:38: La Plataforma ha recibido la orden c3029
# Tiempo: 23:11:38: La Plataforma ha informado a la tienda s251
# Distancia entre la tienda y el cliente: 1.65
# Costo según la distancia: 1654.95
# Valor ofrecido por domicilio 2000.00
# Tiempo: 23:11:38: Domiciliario c1 asignado a la orden c3029
# Tiempo de ida del domiciliario a la tienda: 0:00:25.106321
# Tiempo estimado del domiciliario al cliente: 0:04:19.035997 horas
# Tiempo estimado de entrega: 32.7 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:04:44.142318 horas
# Domiciliario c1 estará disponible a las 23:49:04
# Tiempo: 23:13:16: La Plataforma ha recibido la orden c3030
# Tiempo: 23:13:16: La Plataforma ha informado a la tienda s1
# Distancia entre la tienda y el cliente: 0.94
# Costo según la distancia: 942.71
# Valor ofrecido por domicilio 2000.00
# Domiciliario c4 ha rechazado la orden c3030. 1
# Valor ofrecido por domicilio 2094.27
# Tiempo: 23:15:16: Domiciliario c13 asignado a la orden c3030
# Tiempo de ida del domiciliario a la tienda: 0:00:21.992589
# Tiempo estimado del domiciliario al cliente: 0:02:27.555010 horas
# Tiempo estimado de entrega: 13.21 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:02:49.547599 horas
# Domiciliario c13 estará disponible a las 23:31:18
# Tiempo: 23:18:37: La Plataforma ha recibido la orden c3031
# Tiempo: 23:18:37: La Plataforma ha informado a la tienda s8
# Distancia entre la tienda y el cliente: 1.86
# Costo según la distancia: 1862.96
# Valor ofrecido por domicilio 2000.00
# Tiempo: 23:18:37: Domiciliario c4 asignado a la orden c3031
# Tiempo de ida del domiciliario a la tienda: 0:00:01.330989
# Tiempo estimado del domiciliario al cliente: 0:04:51.594099 horas
# Tiempo estimado de entrega: 32.47 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:04:52.925088 horas
# Domiciliario c4 estará disponible a las 23:55:58
# Tiempo: 23:22:41: La Plataforma ha recibido la orden c3032
# Tiempo: 23:22:41: La Plataforma ha informado a la tienda s1
# Distancia entre la tienda y el cliente: 0.45
# Costo según la distancia: 453.94
# Valor ofrecido por domicilio 2000.00
# Tiempo: 23:22:41: Domiciliario c3 asignado a la orden c3032
# Tiempo de ida del domiciliario a la tienda: 0:01:03.953874
# Tiempo estimado del domiciliario al cliente: 0:02:16.181058 horas
# Tiempo estimado de entrega: 28.25 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:03:20.134932 horas
# Domiciliario c3 estará disponible a las 23:54:16
# Tiempo: 23:23:37: La Plataforma ha recibido la orden c3033
# Tiempo: 23:23:37: La Plataforma ha informado a la tienda s3
# Distancia entre la tienda y el cliente: 0.56
# Costo según la distancia: 561.90
# Valor ofrecido por domicilio 2000.00
# Tiempo: 23:23:37: Domiciliario c6 asignado a la orden c3033
# Tiempo de ida del domiciliario a la tienda: 0:00:31.293198
# Tiempo estimado del domiciliario al cliente: 0:01:27.949995 horas
# Tiempo estimado de entrega: 8.62 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:01:59.243193 horas
# Domiciliario c6 estará disponible a las 23:34:13
# Tiempo: 23:23:44: La Plataforma ha recibido la orden c3034
# Tiempo: 23:23:44: La Plataforma ha informado a la tienda s251
# Distancia entre la tienda y el cliente: 0.36
# Costo según la distancia: 364.82
# Valor ofrecido por domicilio 2000.00
# Tiempo: 23:23:44: Domiciliario c7 asignado a la orden c3034
# Tiempo de ida del domiciliario a la tienda: 0:00:09.774352
# Tiempo estimado del domiciliario al cliente: 0:00:57.102263 horas
# Tiempo estimado de entrega: 28.25 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:01:06.876615 horas
# Domiciliario c7 estará disponible a las 23:53:05
# Tiempo: 23:25:58: La Plataforma ha recibido la orden c3035
# Tiempo: 23:25:58: La Plataforma ha informado a la tienda s4
# Distancia entre la tienda y el cliente: 3.17
# Costo según la distancia: 3167.56
# Valor ofrecido por domicilio 2000.00
# Domiciliario c9 ha rechazado la orden c3035. 1
# Valor ofrecido por domicilio 2316.76
# Domiciliario c12 ha rechazado la orden c3035. 2
# Valor ofrecido por domicilio 2633.51
# Domiciliario c17 ha rechazado la orden c3035. 3
# Valor ofrecido por domicilio 2950.27
# Domiciliario c20 ha rechazado la orden c3035. 4
# Valor ofrecido por domicilio 3267.02
# Tiempo: 23:33:58: Domiciliario c21 asignado a la orden c3035
# Tiempo de ida del domiciliario a la tienda: 0:00:10.470928
# Tiempo estimado del domiciliario al cliente: 0:08:15.791777 horas
# Tiempo estimado de entrega: 39.47 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:08:26.262705 horas
# Domiciliario c21 estará disponible a las 00:21:52
# Tiempo: 23:29:38: La Plataforma ha recibido la orden c3036
# Tiempo: 23:29:38: La Plataforma ha informado a la tienda s251
# Distancia entre la tienda y el cliente: 2.45
# Costo según la distancia: 2448.05
# Valor ofrecido por domicilio 2000.00
# Tiempo: 23:29:38: Domiciliario c9 asignado a la orden c3036
# Tiempo de ida del domiciliario a la tienda: 0:01:04.895806
# Tiempo estimado del domiciliario al cliente: 0:29:22.596218 horas
# Tiempo estimado de entrega: 59.39 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:30:27.492024 horas
# Domiciliario c9 estará disponible a las 00:59:28
# Tiempo: 23:30:34: La Plataforma ha recibido la orden c3037
# Tiempo: 23:30:34: La Plataforma ha informado a la tienda s4
# Distancia entre la tienda y el cliente: 3.55
# Costo según la distancia: 3549.39
# Valor ofrecido por domicilio 2000.00
# Domiciliario c8 ha rechazado la orden c3037. 1
# Valor ofrecido por domicilio 2354.94
# Tiempo: 23:32:34: Domiciliario c17 asignado a la orden c3037
# Tiempo de ida del domiciliario a la tienda: 0:00:17.388522
# Tiempo estimado del domiciliario al cliente: 0:09:15.557098 horas
# Tiempo estimado de entrega: 9.84 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:09:32.945620 horas
# Domiciliario c17 estará disponible a las 23:51:57
# Tiempo: 23:32:56: La Plataforma ha recibido la orden c3038
# Tiempo: 23:32:56: La Plataforma ha informado a la tienda s8
# Distancia entre la tienda y el cliente: 5.44
# Costo según la distancia: 5436.60
# Valor ofrecido por domicilio 2000.00
# Domiciliario c16 ha rechazado la orden c3038. 1
# Valor ofrecido por domicilio 2543.66
# Tiempo: 23:34:56: Domiciliario c22 asignado a la orden c3038
# Tiempo de ida del domiciliario a la tienda: 0:01:05.534000
# Tiempo estimado del domiciliario al cliente: 0:14:10.946650 horas
# Tiempo estimado de entrega: 41.12 minutos
# Tiempo estimado en regreso al punto inicial el domiciliario: 0:15:16.480650 horas
# Domiciliario c22 estará disponible a las 00:31:19
# Ganancia Total Domiciliarios: 6173946.25
# Ganancia Total Tiendas: 172221476.77
# Ganancia Total Plataforma: 50955019.38
# Ventas Totales (Costo Total al Usuario): 228937154.53
# Órdenes Perdidas: ['c26', 'c239', 'c279', 'c294', 'c297', 'c304', 'c325', 'c362', 'c371', 'c419', 'c434', 'c455', 'c472', 'c487', 'c498', 'c522', 'c543', 'c579', 'c580', 'c689', 'c754', 'c757', 'c773', 'c881', 'c952', 'c1024', 'c1040', 'c1103', 'c1135', 'c1235', 'c1339', 'c1369', 'c1428', 'c1498', 'c1522', 'c1537', 'c1559', 'c1736', 'c1758', 'c1785', 'c1863', 'c1865', 'c1866', 'c1879', 'c1893', 'c1953', 'c1968', 'c1978', 'c2039', 'c2043', 'c2046', 'c2072', 'c2094', 'c2118', 'c2151', 'c2178', 'c2223', 'c2226', 'c2253', 'c2312', 'c2388', 'c2390', 'c2419', 'c2480', 'c2518', 'c2539', 'c2566', 'c2587', 'c2598', 'c2608', 'c2640', 'c2708', 'c2777', 'c2780', 'c2796', 'c2816', 'c2847', 'c2857', 'c2917', 'c2957', 'c2998', 'c3023', 'c3027']
# Ganancias perdidas - Domiciliarios: 343792.8689499757
# Ganancias perdidas - Tiendas: 5856508.07562707
# Ganancias perdidas - Plataforma: 629157.9449587465
# ordenes_aceptadas_sin_rechazo: 18814
# ordenes_rechazadas_una_vez: 5609
# ordenes_rechazadas_dos_veces: 2622
# ordenes_rechazadas_tres_veces: 1583
# ordenes_rechazadas_cuatro_veces: 960
# ordenes_rechazadas_definitivamente: 860

# %%
# ---------> Para plataforma y total
# Crear un diccionario con los datos de la plataforma
datos_plataforma = {
    'Descripción': ['Ganancia plataforma', 'Ventas totales', 'Ganancia total domiciliarios', 'Ganancia total tiendas', 'Costo de oportunidad por ordenes rechazadas definitivamente', 'Total ordenes rechazadas definitivamente', 'Ganancias perdidas tiendas', 'Ganancias perdidas plataforma', 'Ganancias perdidas domiciliarios'],
    'Valor': [
        plataforma.ganancia_total_plataforma, 
        plataforma.ventas_totales, 
        plataforma.ganancia_total_domiciliarios, 
        plataforma.ganancia_total_tiendas, 
        '', # Costo de oportunidad no se calculó en el código, así que se deja en blanco o se agrega un cálculo si lo tienes
        len(plataforma.ordenes_perdidas), 
        plataforma.ganancias_perdidas_tiendas, 
        plataforma.ganancias_perdidas_plataforma, 
        plataforma.ganancias_perdidas_domiciliarios
    ]
}

# Convertir el diccionario en un DataFrame
df_plataforma = pd.DataFrame(datos_plataforma)

print(df_plataforma)
# Out:
#                                          Descripción            Valor
# 0                                Ganancia plataforma   4123064.609832
# 1                                     Ventas totales  31060539.873298
# 2                       Ganancia total domiciliarios   1178013.348458
# 3                             Ganancia total tiendas  23164275.925875
# 4  Costo de oportunidad por ordenes rechazadas de...
# 5           Total ordenes rechazadas definitivamente                6
# 6                         Ganancias perdidas tiendas    369055.214766
# 7                      Ganancias perdidas plataforma     64928.028068
# 8                   Ganancias perdidas domiciliarios     24964.811936
